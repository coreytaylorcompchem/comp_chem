# %% [markdown]
# # Build a hERG GNN model - updated with larger balanced sample.

# %% [markdown]
# This notebook shows how to train a binary classification deep learning model to predict hERG activity at 10 uM (0 = inactive, 1 = active).

# %% [markdown]
# Additionally, we saw that taking a balanced random sample, whilst improving model performance, was not enough. The size of the balanced dataset might impact model performance too.

# %% [markdown]
# So, in this case, instead of taking a random balanced sample of 1000 / class, we take the largest possible random balanced sample from the dataset prior to training the model.

# %%
import torch
import torch.nn.functional as F
from torch.nn import Linear
from torch_geometric.data import Data, Dataset, DataLoader
from torch_geometric.nn import GCNConv, global_mean_pool, BatchNorm, NNConv
from rdkit import Chem
from rdkit.Chem import rdmolops
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns

import pathlib
from pathlib import Path

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
target = 'herg'
uniprot = 'Q12809'

# %%
# define paths
HERE = Path(pathlib.Path.cwd())
DATA = HERE / f"data_{target}"
DATA.mkdir(parents=True, exist_ok=True)

# %%
# Load chembl data

df = pd.read_csv(f'{DATA}/{target}_chembl.csv',index_col=None)
df['herg_active'] = np.where(df['pIC50'] > 5, 1, 0) # 1=active, 0=inactive @ 10 uM
df.head(20)
# Out:
#     Index molecule_chembl_id     IC50 units  \
# 0       0       CHEMBL443476     88.0    nM
# 1       1        CHEMBL53661    137.0    nM
# 2       2       CHEMBL299390   1480.0    nM
# 3       3        CHEMBL12186     10.0    nM
# 4       4       CHEMBL556312     23.5    nM
# 5       5         CHEMBL1729     45.0    nM
# 6       6         CHEMBL6966    143.0    nM
# 7       7        CHEMBL55835    579.0    nM
# 8       8        CHEMBL17157     56.0    nM
# 9       9       CHEMBL298978      6.2    nM
# 10     10        CHEMBL53871  15700.0    nM
# 11     11       CHEMBL300927  75000.0    nM
# 12     12          CHEMBL473     10.0    nM
# 13     13        CHEMBL52348  26000.0    nM
# 14     14        CHEMBL53866   2200.0    nM
# 15     15       CHEMBL301956     11.0    nM
# 16     16        CHEMBL53321   1947.0    nM
# 17     17          CHEMBL914  23000.0    nM
# 18     18        CHEMBL52794   4550.0    nM
# 19     19           CHEMBL54     32.0    nM
#
#                                                smiles     pIC50  herg_active
# 0   O=C1NCCN1CCN1CCC(c2cn(-c3ccccc3)c3ccc(Cl)cc23)CC1  7.055517            1
# 1    O=C1NCCN1CCN1CCC(c2cn(C3CCCCC3)c3ccc(Cl)cc23)CC1  6.863279            1
# 2              CCC(CC)c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  5.829738            1
# 3   O=C1NCCN1CCN1CC=C(c2cn(-c3ccc(F)cc3)c3ccc(Cl)c...  8.000000            1
# 4     O=C1NCCN1CCN1CCC(C2CN(c3ccc(F)cc3)c3ccccc32)CC1  7.628932            1
# 5   COc1cc(N)c(Cl)cc1C(=O)NC1CCN(CCCOc2ccc(F)cc2)C...  7.346787            1
# 6   COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...  6.844664            1
# 7   O=C(O)Cc1ccc(-n2cc(C3CCN(CCN4CCNC4=O)CC3)c3cc(...  6.237321            1
# 8   CC(C)(C)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)c3ccc...  7.251812            1
# 9    Fc1ccc(-n2cc(C3CCN(CCN4CCN=C4S)CC3)c3ccccc32)cc1  8.207608            1
# 10          CCC(O)(CC)c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  4.804100            0
# 11  O=C(O)c1ccc(-n2cc(C3CCN(CCN4CCNC4=O)CC3)c3cc(C...  4.124939            0
# 12  CN(CCOc1ccc(NS(C)(=O)=O)cc1)CCc1ccc(NS(C)(=O)=...  8.000000            1
# 13                 CCCc1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  4.585027            0
# 14              CCC(O)c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  5.657577            1
# 15              CN(C)Cc1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  7.958607            1
# 16             CCC(=O)c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  5.710634            1
# 17  CC(C)(C(=O)O)c1ccc(C(O)CCCN2CCC(C(O)(c3ccccc3)...  4.638272            0
# 18               CC(O)c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  5.341989            1
# 19       O=C(CCCN1CCC(O)(c2ccc(Cl)cc2)CC1)c1ccc(F)cc1  7.494850            1

# %% [markdown]
# Are the data labels balanced?

# %%
counts = df['herg_active'].value_counts().sort_index()  # ensures 0 comes before 1

counts.plot(kind='bar')
plt.xticks([0, 1], ['0', '1'])
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('hERG active (0/1)')
plt.savefig("herg_active.png", dpi=300)
plt.show()

# %%
def get_largest_balanced_sample(df, label_col='herg_active', random_state=42):
    min_class_count = df[label_col].value_counts().min()
    df_balanced = pd.concat([
        df[df[label_col] == 0].sample(n=min_class_count, random_state=random_state),
        df[df[label_col] == 1].sample(n=min_class_count, random_state=random_state)
    ])
    return df_balanced.sample(frac=1, random_state=random_state).reset_index(drop=True)

# %%
df_herg = get_largest_balanced_sample(df)
len(df_herg)
# Out:
# 4480

# %%
smiles_list = df_herg.smiles.to_list()
labels = df_herg.herg_active.to_list()

# %%
# One-hot encoder with "unknown" category fallback

def one_hot_encoding(x, allowable_set):
    if x not in allowable_set:
        x = allowable_set[-1]  # unknown
    return [int(x == s) for s in allowable_set]

def get_atom_features(atom):
    features = []
    features += one_hot_encoding(atom.GetSymbol(),
                                   ['C', 'N', 'O', 'F', 'P', 'S', 'Cl', 'Br', 'I', 'H', 'B', 'Si', 'Se', 'As', 'Al', 'Zn', 'Cu', 'Ni', 'Fe', 'other'])  # 21
    features += one_hot_encoding(atom.GetHybridization(),
                                  [Chem.rdchem.HybridizationType.SP,
                                   Chem.rdchem.HybridizationType.SP2,
                                   Chem.rdchem.HybridizationType.SP3,
                                   Chem.rdchem.HybridizationType.SP3D,
                                   Chem.rdchem.HybridizationType.SP3D2,
                                   Chem.rdchem.HybridizationType.UNSPECIFIED])
    features += [atom.GetDegree()]  # Number of bonds
    features += [atom.GetFormalCharge()]
    features += [atom.GetNumRadicalElectrons()]
    features += [int(atom.GetIsAromatic())]
    return np.array(features, dtype=np.float32)

def get_bond_features(bond):
    bond_type = bond.GetBondType()
    return np.array([
        int(bond_type == Chem.rdchem.BondType.SINGLE),
        int(bond_type == Chem.rdchem.BondType.DOUBLE),
        int(bond_type == Chem.rdchem.BondType.TRIPLE),
        int(bond_type == Chem.rdchem.BondType.AROMATIC),
        int(bond.GetIsConjugated()),
        int(bond.IsInRing()),
    ], dtype=np.float32)

# %%
def mol_to_graph(smiles: str, label: int = None):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None

    atom_features = [get_atom_features(atom) for atom in mol.GetAtoms()]
    x = torch.tensor(atom_features, dtype=torch.float)

    edge_index = []
    edge_attr = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        bond_feat = get_bond_features(bond)
        edge_index += [[i, j], [j, i]]
        edge_attr += [bond_feat, bond_feat]

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    edge_attr = torch.tensor(edge_attr, dtype=torch.float)

    data = Data(x=x, edge_index=edge_index, edge_attr=edge_attr)

    if label is not None:
        data.y = torch.tensor([label], dtype=torch.float)

    return data

# %%
data_list = []

for smi, lbl in zip(smiles_list, labels):
    data = mol_to_graph(smi, lbl)
    if data is not None:
        data_list.append(data)

from torch_geometric.loader import DataLoader

loader = DataLoader(data_list, batch_size=16, shuffle=True)
# Out:
# /tmp/ipykernel_7621/4096140373.py:7: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   x = torch.tensor(atom_features, dtype=torch.float)

# %%
# Use a GCN model, as it is 'good enough'.

class GCN(torch.nn.Module):
    def __init__(self, input_dim, edge_dim, hidden_dim=128):
        super().__init__()

        self.edge_mlp = torch.nn.Sequential(
            torch.nn.Linear(edge_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, input_dim * hidden_dim) 
        )

        self.conv1 = NNConv(input_dim, hidden_dim, self.edge_mlp, aggr='mean')

        self.edge_mlp2 = torch.nn.Sequential(
            torch.nn.Linear(edge_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, hidden_dim * hidden_dim)
        )

        self.conv2 = NNConv(hidden_dim, hidden_dim, self.edge_mlp2, aggr='mean')

        self.lin = torch.nn.Linear(hidden_dim, 1)

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch

        x = F.relu(self.conv1(x, edge_index, edge_attr))
        x = F.relu(self.conv2(x, edge_index, edge_attr))

        x = global_mean_pool(x, batch)
        return self.lin(x).squeeze(1)

# %%
# input_dim = data_list[0].x.shape[1]
# edge_dim = data_list[0].edge_attr.shape[1]
# model = GCN(input_dim, edge_dim).to(device)

# optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
# loss_fn = torch.nn.BCEWithLogitsLoss()

# model.train()

# for epoch in range(100):
#     total_loss = 0
#     for batch in loader:
#         batch = batch.to(device)
#         optimizer.zero_grad()
#         out = model(batch)

#         # Ensure batch.y is shape [batch_size]
#         y = batch.y.view(-1)

#         loss = loss_fn(out, y)
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
#     print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

# %% [markdown]
# ### With early stopping

# %%
from sklearn.model_selection import train_test_split

train_list, val_list = train_test_split(data_list, test_size=0.2, random_state=42, stratify=[d.y.item() for d in data_list])

train_loader = DataLoader(train_list, batch_size=32, shuffle=True)
val_loader = DataLoader(val_list, batch_size=32)

# %%
def train_epoch(model, loader, optimizer, loss_fn, device):
    model.train()
    total_loss = 0
    for batch in loader:
        batch = batch.to(device)
        optimizer.zero_grad()
        out = model(batch)
        loss = loss_fn(out, batch.y.float())
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def eval_epoch(model, loader, loss_fn, device):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for batch in loader:
            batch = batch.to(device)
            out = model(batch)
            loss = loss_fn(out, batch.y.float())
            total_loss += loss.item()
    return total_loss / len(loader)

# %%
def train_with_early_stopping(params):
    model = GCN(input_dim=params['input_dim'], edge_dim=params['edge_dim'], hidden_dim=params['hidden_dim']).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=params.get('pos_weight'))

    best_val_loss = float('inf')
    patience = 10
    patience_counter = 0

    for epoch in range(100):
        train_loss = train_epoch(model, train_loader, optimizer, loss_fn, device)
        val_loss = eval_epoch(model, val_loader, loss_fn, device)
        print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), 'best_model.pth')  # Save best model
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break

    # Load best model weights
    model.load_state_dict(torch.load('best_model.pth'))
    return model

# %% [markdown]
# With hyperparameter tuning.

# %%
import itertools

#input_dim = data_list[0].x.shape[1]
#edge_dim = data_list[0].edge_attr.shape[1] if data_list[0].edge_attr is not None else 0

input_dim = data_list[0].x.shape[1]
edge_dim = data_list[0].edge_attr.shape[1]
model = GCN(input_dim=input_dim, edge_dim=edge_dim)

param_grid = {
    'lr': [0.01, 0.001],
    'hidden_dim': [64, 128],
    'pos_weight': [None, torch.tensor([2.0], device=device)]  # Example for weighted loss
}

best_model = None
best_val_loss = float('inf')
best_params = None

for lr, hidden_dim, pos_weight in itertools.product(param_grid['lr'], param_grid['hidden_dim'], param_grid['pos_weight']):
    params = {
        'lr': lr,
        'hidden_dim': hidden_dim,
        'pos_weight': pos_weight,
        'input_dim': input_dim,
        'edge_dim': edge_dim
    }
    print(f"Training with lr={lr}, hidden_dim={hidden_dim}, pos_weight={pos_weight}")
    # params = {'lr': lr, 'hidden_dim': hidden_dim, 'pos_weight': pos_weight, 'input_dim': input_dim}
    model = train_with_early_stopping(params)
    
    val_loss = eval_epoch(model, val_loader, torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight), device)
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model
        best_params = params

print(f"Best params: {best_params}")
# Out:
# Training with lr=0.01, hidden_dim=64, pos_weight=None
# Epoch 1 | Train Loss: 0.7050 | Val Loss: 0.6931
# Epoch 2 | Train Loss: 0.6933 | Val Loss: 0.6933
# Epoch 3 | Train Loss: 0.6935 | Val Loss: 0.6932
# Epoch 4 | Train Loss: 0.6935 | Val Loss: 0.6931
# Epoch 5 | Train Loss: 0.6934 | Val Loss: 0.6932
# Epoch 6 | Train Loss: 0.6936 | Val Loss: 0.6932
# Epoch 7 | Train Loss: 0.6934 | Val Loss: 0.6931
# Epoch 8 | Train Loss: 0.6935 | Val Loss: 0.6933
# Epoch 9 | Train Loss: 0.6933 | Val Loss: 0.6931
# Epoch 10 | Train Loss: 0.6933 | Val Loss: 0.6932
# Epoch 11 | Train Loss: 0.6935 | Val Loss: 0.6931
# Epoch 12 | Train Loss: 0.6920 | Val Loss: 0.6823
# Epoch 13 | Train Loss: 0.6853 | Val Loss: 0.6769
# Epoch 14 | Train Loss: 0.6787 | Val Loss: 0.6791
# Epoch 15 | Train Loss: 0.6767 | Val Loss: 0.6737
# Epoch 16 | Train Loss: 0.6765 | Val Loss: 0.6769
# Epoch 17 | Train Loss: 0.6772 | Val Loss: 0.6719
# Epoch 18 | Train Loss: 0.6762 | Val Loss: 0.6714
# Epoch 19 | Train Loss: 0.6732 | Val Loss: 0.6733
# Epoch 20 | Train Loss: 0.6681 | Val Loss: 0.6708
# Epoch 21 | Train Loss: 0.6673 | Val Loss: 0.6661
# Epoch 22 | Train Loss: 0.6640 | Val Loss: 0.6776
# Epoch 23 | Train Loss: 0.6641 | Val Loss: 0.6618
# Epoch 24 | Train Loss: 0.6638 | Val Loss: 0.6623
# Epoch 25 | Train Loss: 0.6595 | Val Loss: 0.6608
# Epoch 26 | Train Loss: 0.6565 | Val Loss: 0.6591
# Epoch 27 | Train Loss: 0.6597 | Val Loss: 0.6610
# Epoch 28 | Train Loss: 0.6564 | Val Loss: 0.6596
# Epoch 29 | Train Loss: 0.6557 | Val Loss: 0.6595
# Epoch 30 | Train Loss: 0.6560 | Val Loss: 0.6563
# Epoch 31 | Train Loss: 0.6556 | Val Loss: 0.6550
# Epoch 32 | Train Loss: 0.6556 | Val Loss: 0.6578
# Epoch 33 | Train Loss: 0.6533 | Val Loss: 0.6650
# Epoch 34 | Train Loss: 0.6540 | Val Loss: 0.6548
# Epoch 35 | Train Loss: 0.6538 | Val Loss: 0.6566
# Epoch 36 | Train Loss: 0.6532 | Val Loss: 0.6570
# Epoch 37 | Train Loss: 0.6531 | Val Loss: 0.6641
# Epoch 38 | Train Loss: 0.6535 | Val Loss: 0.6585
# Epoch 39 | Train Loss: 0.6539 | Val Loss: 0.6666
# Epoch 40 | Train Loss: 0.6519 | Val Loss: 0.6573
# Epoch 41 | Train Loss: 0.6543 | Val Loss: 0.6558
# Epoch 42 | Train Loss: 0.6506 | Val Loss: 0.6649
# Epoch 43 | Train Loss: 0.6518 | Val Loss: 0.6553
# Epoch 44 | Train Loss: 0.6555 | Val Loss: 0.6590
# Early stopping triggered
# Training with lr=0.01, hidden_dim=64, pos_weight=tensor([2.], device='cuda:0')
# Epoch 1 | Train Loss: 0.9728 | Val Loss: 0.9614
# Epoch 2 | Train Loss: 0.9487 | Val Loss: 0.9351
# Epoch 3 | Train Loss: 0.9357 | Val Loss: 0.9292
# Epoch 4 | Train Loss: 0.9314 | Val Loss: 0.9184
# Epoch 5 | Train Loss: 0.9234 | Val Loss: 0.9208
# Epoch 6 | Train Loss: 0.9140 | Val Loss: 0.8923
# Epoch 7 | Train Loss: 0.9045 | Val Loss: 0.9000
# Epoch 8 | Train Loss: 0.9116 | Val Loss: 0.9090
# Epoch 9 | Train Loss: 0.8995 | Val Loss: 0.8878
# Epoch 10 | Train Loss: 0.8945 | Val Loss: 0.8865
# Epoch 11 | Train Loss: 0.8856 | Val Loss: 0.8977
# Epoch 12 | Train Loss: 0.8901 | Val Loss: 0.8928
# Epoch 13 | Train Loss: 0.8823 | Val Loss: 0.8874
# Epoch 14 | Train Loss: 0.8785 | Val Loss: 0.8778
# Epoch 15 | Train Loss: 0.8795 | Val Loss: 0.8669
# Epoch 16 | Train Loss: 0.8769 | Val Loss: 0.8784
# Epoch 17 | Train Loss: 0.8737 | Val Loss: 0.8669
# Epoch 18 | Train Loss: 0.8752 | Val Loss: 0.8943
# Epoch 19 | Train Loss: 0.8665 | Val Loss: 0.8638
# Epoch 20 | Train Loss: 0.8690 | Val Loss: 0.8633
# Epoch 21 | Train Loss: 0.8654 | Val Loss: 0.8645
# Epoch 22 | Train Loss: 0.8634 | Val Loss: 0.8750
# Epoch 23 | Train Loss: 0.8594 | Val Loss: 0.8649
# Epoch 24 | Train Loss: 0.8499 | Val Loss: 0.8601
# Epoch 25 | Train Loss: 0.8598 | Val Loss: 0.8564
# Epoch 26 | Train Loss: 0.8483 | Val Loss: 0.8533
# Epoch 27 | Train Loss: 0.8492 | Val Loss: 0.8628
# Epoch 28 | Train Loss: 0.8552 | Val Loss: 0.8653
# Epoch 29 | Train Loss: 0.8590 | Val Loss: 0.8557
# Epoch 30 | Train Loss: 0.8452 | Val Loss: 0.8822
# Epoch 31 | Train Loss: 0.8499 | Val Loss: 0.8640
# Epoch 32 | Train Loss: 0.8451 | Val Loss: 0.8602
# Epoch 33 | Train Loss: 0.8414 | Val Loss: 0.8634
# Epoch 34 | Train Loss: 0.8417 | Val Loss: 0.8652
# Epoch 35 | Train Loss: 0.8355 | Val Loss: 0.8457
# Epoch 36 | Train Loss: 0.8396 | Val Loss: 0.8633
# Epoch 37 | Train Loss: 0.8367 | Val Loss: 0.8578
# Epoch 38 | Train Loss: 0.8305 | Val Loss: 0.8521
# Epoch 39 | Train Loss: 0.8329 | Val Loss: 0.8520
# Epoch 40 | Train Loss: 0.8331 | Val Loss: 0.8538
# Epoch 41 | Train Loss: 0.8322 | Val Loss: 0.8577
# Epoch 42 | Train Loss: 0.8284 | Val Loss: 0.8512
# Epoch 43 | Train Loss: 0.8277 | Val Loss: 0.8561
# Epoch 44 | Train Loss: 0.8283 | Val Loss: 0.8520
# Epoch 45 | Train Loss: 0.8206 | Val Loss: 0.8488
# Early stopping triggered
# Training with lr=0.01, hidden_dim=128, pos_weight=None
# Epoch 1 | Train Loss: 0.8572 | Val Loss: 0.6935
# Epoch 2 | Train Loss: 0.6934 | Val Loss: 0.6935
# Epoch 3 | Train Loss: 0.6937 | Val Loss: 0.6932
# Epoch 4 | Train Loss: 0.6933 | Val Loss: 0.6932
# Epoch 5 | Train Loss: 0.6934 | Val Loss: 0.6932
# Epoch 6 | Train Loss: 0.6934 | Val Loss: 0.6932
# Epoch 7 | Train Loss: 0.6935 | Val Loss: 0.6933
# Epoch 8 | Train Loss: 0.6934 | Val Loss: 0.6932
# Epoch 9 | Train Loss: 0.6934 | Val Loss: 0.6931
# Epoch 10 | Train Loss: 0.6935 | Val Loss: 0.6931
# Epoch 11 | Train Loss: 0.6934 | Val Loss: 0.6931
# Epoch 12 | Train Loss: 0.6934 | Val Loss: 0.6933
# Epoch 13 | Train Loss: 0.6936 | Val Loss: 0.6931
# Epoch 14 | Train Loss: 0.6934 | Val Loss: 0.6930
# Epoch 15 | Train Loss: 0.6935 | Val Loss: 0.6930
# Epoch 16 | Train Loss: 0.6934 | Val Loss: 0.6930
# Epoch 17 | Train Loss: 0.6935 | Val Loss: 0.6929
# Epoch 18 | Train Loss: 0.6933 | Val Loss: 0.6930
# Epoch 19 | Train Loss: 0.6934 | Val Loss: 0.6929
# Epoch 20 | Train Loss: 0.6942 | Val Loss: 0.6929
# Epoch 21 | Train Loss: 0.6936 | Val Loss: 0.6929
# Epoch 22 | Train Loss: 0.6936 | Val Loss: 0.6928
# Epoch 23 | Train Loss: 0.6936 | Val Loss: 0.6929
# Epoch 24 | Train Loss: 0.6935 | Val Loss: 0.6928
# Epoch 25 | Train Loss: 0.6933 | Val Loss: 0.6927
# Epoch 26 | Train Loss: 0.6932 | Val Loss: 0.6926
# Epoch 27 | Train Loss: 0.6932 | Val Loss: 0.6926
# Epoch 28 | Train Loss: 0.6933 | Val Loss: 0.6926
# Epoch 29 | Train Loss: 0.6930 | Val Loss: 0.6931
# Epoch 30 | Train Loss: 0.6931 | Val Loss: 0.6928
# Epoch 31 | Train Loss: 0.6932 | Val Loss: 0.6929
# Epoch 32 | Train Loss: 0.6936 | Val Loss: 0.6924
# Epoch 33 | Train Loss: 0.6932 | Val Loss: 0.6926
# Epoch 34 | Train Loss: 0.6929 | Val Loss: 0.6926
# Epoch 35 | Train Loss: 0.6933 | Val Loss: 0.6927
# Epoch 36 | Train Loss: 0.6930 | Val Loss: 0.6927
# Epoch 37 | Train Loss: 0.6931 | Val Loss: 0.6927
# Epoch 38 | Train Loss: 0.6934 | Val Loss: 0.6927
# Epoch 39 | Train Loss: 0.6931 | Val Loss: 0.6930
# Epoch 40 | Train Loss: 0.6933 | Val Loss: 0.6930
# Epoch 41 | Train Loss: 0.6930 | Val Loss: 0.6929
# Epoch 42 | Train Loss: 0.6933 | Val Loss: 0.6929
# Early stopping triggered
# Training with lr=0.01, hidden_dim=128, pos_weight=tensor([2.], device='cuda:0')
# Epoch 1 | Train Loss: 1.1742 | Val Loss: 0.9691
# Epoch 2 | Train Loss: 0.9519 | Val Loss: 0.9366
# Epoch 3 | Train Loss: 0.9373 | Val Loss: 0.9117
# Epoch 4 | Train Loss: 0.9256 | Val Loss: 0.9073
# Epoch 5 | Train Loss: 0.9274 | Val Loss: 0.9062
# Epoch 6 | Train Loss: 0.9156 | Val Loss: 0.9061
# Epoch 7 | Train Loss: 0.9160 | Val Loss: 0.9109
# Epoch 8 | Train Loss: 0.9148 | Val Loss: 0.9054
# Epoch 9 | Train Loss: 0.9045 | Val Loss: 0.9102
# Epoch 10 | Train Loss: 0.9078 | Val Loss: 0.8945
# Epoch 11 | Train Loss: 0.9073 | Val Loss: 0.8952
# Epoch 12 | Train Loss: 0.8970 | Val Loss: 0.9005
# Epoch 13 | Train Loss: 0.8999 | Val Loss: 0.8878
# Epoch 14 | Train Loss: 0.8953 | Val Loss: 0.8873
# Epoch 15 | Train Loss: 0.8863 | Val Loss: 0.8754
# Epoch 16 | Train Loss: 0.8869 | Val Loss: 0.8826
# Epoch 17 | Train Loss: 0.8839 | Val Loss: 0.8742
# Epoch 18 | Train Loss: 0.8826 | Val Loss: 0.8822
# Epoch 19 | Train Loss: 0.8839 | Val Loss: 0.8769
# Epoch 20 | Train Loss: 0.8758 | Val Loss: 0.8889
# Epoch 21 | Train Loss: 0.8782 | Val Loss: 0.8956
# Epoch 22 | Train Loss: 0.8829 | Val Loss: 0.8831
# Epoch 23 | Train Loss: 0.8710 | Val Loss: 0.8710
# Epoch 24 | Train Loss: 0.8777 | Val Loss: 0.8781
# Epoch 25 | Train Loss: 0.8807 | Val Loss: 0.8741
# Epoch 26 | Train Loss: 0.8673 | Val Loss: 0.8677
# Epoch 27 | Train Loss: 0.8693 | Val Loss: 0.8592
# Epoch 28 | Train Loss: 0.8703 | Val Loss: 0.8798
# Epoch 29 | Train Loss: 0.8734 | Val Loss: 0.8775
# Epoch 30 | Train Loss: 0.8640 | Val Loss: 0.8693
# Epoch 31 | Train Loss: 0.8658 | Val Loss: 0.8798
# Epoch 32 | Train Loss: 0.8654 | Val Loss: 0.8660
# Epoch 33 | Train Loss: 0.8622 | Val Loss: 0.8690
# Epoch 34 | Train Loss: 0.8646 | Val Loss: 0.8847
# Epoch 35 | Train Loss: 0.8620 | Val Loss: 0.9014
# Epoch 36 | Train Loss: 0.8558 | Val Loss: 0.8756
# Epoch 37 | Train Loss: 0.8608 | Val Loss: 0.8704
# Early stopping triggered
# Training with lr=0.001, hidden_dim=64, pos_weight=None
# Epoch 1 | Train Loss: 0.6877 | Val Loss: 0.6726
# Epoch 2 | Train Loss: 0.6720 | Val Loss: 0.6647
# Epoch 3 | Train Loss: 0.6623 | Val Loss: 0.6518
# Epoch 4 | Train Loss: 0.6567 | Val Loss: 0.6661
# Epoch 5 | Train Loss: 0.6521 | Val Loss: 0.6503
# Epoch 6 | Train Loss: 0.6479 | Val Loss: 0.6459
# Epoch 7 | Train Loss: 0.6446 | Val Loss: 0.6358
# Epoch 8 | Train Loss: 0.6400 | Val Loss: 0.6539
# Epoch 9 | Train Loss: 0.6290 | Val Loss: 0.6273
# Epoch 10 | Train Loss: 0.6284 | Val Loss: 0.6252
# Epoch 11 | Train Loss: 0.6164 | Val Loss: 0.6191
# Epoch 12 | Train Loss: 0.6133 | Val Loss: 0.6202
# Epoch 13 | Train Loss: 0.6110 | Val Loss: 0.6234
# Epoch 14 | Train Loss: 0.6078 | Val Loss: 0.6188
# Epoch 15 | Train Loss: 0.6033 | Val Loss: 0.6680
# Epoch 16 | Train Loss: 0.6024 | Val Loss: 0.6255
# Epoch 17 | Train Loss: 0.5999 | Val Loss: 0.6393
# Epoch 18 | Train Loss: 0.5926 | Val Loss: 0.6144
# Epoch 19 | Train Loss: 0.5984 | Val Loss: 0.6202
# Epoch 20 | Train Loss: 0.5866 | Val Loss: 0.6037
# Epoch 21 | Train Loss: 0.5869 | Val Loss: 0.6253
# Epoch 22 | Train Loss: 0.5826 | Val Loss: 0.6063
# Epoch 23 | Train Loss: 0.5799 | Val Loss: 0.6094
# Epoch 24 | Train Loss: 0.5719 | Val Loss: 0.6100
# Epoch 25 | Train Loss: 0.5701 | Val Loss: 0.6222
# Epoch 26 | Train Loss: 0.5736 | Val Loss: 0.5972
# Epoch 27 | Train Loss: 0.5627 | Val Loss: 0.6207
# Epoch 28 | Train Loss: 0.5634 | Val Loss: 0.5983
# Epoch 29 | Train Loss: 0.5573 | Val Loss: 0.6083
# Epoch 30 | Train Loss: 0.5632 | Val Loss: 0.6282
# Epoch 31 | Train Loss: 0.5582 | Val Loss: 0.5999
# Epoch 32 | Train Loss: 0.5510 | Val Loss: 0.6020
# Epoch 33 | Train Loss: 0.5466 | Val Loss: 0.6062
# Epoch 34 | Train Loss: 0.5497 | Val Loss: 0.5978
# Epoch 35 | Train Loss: 0.5425 | Val Loss: 0.6099
# Epoch 36 | Train Loss: 0.5404 | Val Loss: 0.5958
# Epoch 37 | Train Loss: 0.5354 | Val Loss: 0.5939
# Epoch 38 | Train Loss: 0.5340 | Val Loss: 0.5879
# Epoch 39 | Train Loss: 0.5338 | Val Loss: 0.5902
# Epoch 40 | Train Loss: 0.5308 | Val Loss: 0.5887
# Epoch 41 | Train Loss: 0.5257 | Val Loss: 0.5934
# Epoch 42 | Train Loss: 0.5281 | Val Loss: 0.6073
# Epoch 43 | Train Loss: 0.5213 | Val Loss: 0.5754
# Epoch 44 | Train Loss: 0.5203 | Val Loss: 0.5917
# Epoch 45 | Train Loss: 0.5203 | Val Loss: 0.5759
# Epoch 46 | Train Loss: 0.5178 | Val Loss: 0.5988
# Epoch 47 | Train Loss: 0.5166 | Val Loss: 0.5796
# Epoch 48 | Train Loss: 0.5148 | Val Loss: 0.5845
# Epoch 49 | Train Loss: 0.5080 | Val Loss: 0.5970
# Epoch 50 | Train Loss: 0.5103 | Val Loss: 0.5848
# Epoch 51 | Train Loss: 0.5035 | Val Loss: 0.5822
# Epoch 52 | Train Loss: 0.5053 | Val Loss: 0.5779
# Epoch 53 | Train Loss: 0.5005 | Val Loss: 0.6033
# Early stopping triggered
# Training with lr=0.001, hidden_dim=64, pos_weight=tensor([2.], device='cuda:0')
# Epoch 1 | Train Loss: 0.9529 | Val Loss: 0.9354
# Epoch 2 | Train Loss: 0.9312 | Val Loss: 0.9221
# Epoch 3 | Train Loss: 0.9159 | Val Loss: 0.9202
# Epoch 4 | Train Loss: 0.9092 | Val Loss: 0.8933
# Epoch 5 | Train Loss: 0.8962 | Val Loss: 0.8891
# Epoch 6 | Train Loss: 0.8994 | Val Loss: 0.8899
# Epoch 7 | Train Loss: 0.8842 | Val Loss: 0.8756
# Epoch 8 | Train Loss: 0.8811 | Val Loss: 0.8853
# Epoch 9 | Train Loss: 0.8748 | Val Loss: 0.8776
# Epoch 10 | Train Loss: 0.8685 | Val Loss: 0.8726
# Epoch 11 | Train Loss: 0.8624 | Val Loss: 0.8589
# Epoch 12 | Train Loss: 0.8636 | Val Loss: 0.8739
# Epoch 13 | Train Loss: 0.8532 | Val Loss: 0.8465
# Epoch 14 | Train Loss: 0.8503 | Val Loss: 0.8517
# Epoch 15 | Train Loss: 0.8487 | Val Loss: 0.8393
# Epoch 16 | Train Loss: 0.8458 | Val Loss: 0.8483
# Epoch 17 | Train Loss: 0.8319 | Val Loss: 0.8339
# Epoch 18 | Train Loss: 0.8316 | Val Loss: 0.8559
# Epoch 19 | Train Loss: 0.8248 | Val Loss: 0.8328
# Epoch 20 | Train Loss: 0.8191 | Val Loss: 0.8318
# Epoch 21 | Train Loss: 0.8093 | Val Loss: 0.8349
# Epoch 22 | Train Loss: 0.8111 | Val Loss: 0.8312
# Epoch 23 | Train Loss: 0.8076 | Val Loss: 0.8382
# Epoch 24 | Train Loss: 0.8103 | Val Loss: 0.8200
# Epoch 25 | Train Loss: 0.7944 | Val Loss: 0.8292
# Epoch 26 | Train Loss: 0.7913 | Val Loss: 0.8251
# Epoch 27 | Train Loss: 0.7851 | Val Loss: 0.8273
# Epoch 28 | Train Loss: 0.7808 | Val Loss: 0.8391
# Epoch 29 | Train Loss: 0.7783 | Val Loss: 0.8117
# Epoch 30 | Train Loss: 0.7711 | Val Loss: 0.8671
# Epoch 31 | Train Loss: 0.7767 | Val Loss: 0.8472
# Epoch 32 | Train Loss: 0.7728 | Val Loss: 0.7991
# Epoch 33 | Train Loss: 0.7636 | Val Loss: 0.8037
# Epoch 34 | Train Loss: 0.7617 | Val Loss: 0.8015
# Epoch 35 | Train Loss: 0.7588 | Val Loss: 0.8157
# Epoch 36 | Train Loss: 0.7557 | Val Loss: 0.7960
# Epoch 37 | Train Loss: 0.7505 | Val Loss: 0.7943
# Epoch 38 | Train Loss: 0.7465 | Val Loss: 0.7997
# Epoch 39 | Train Loss: 0.7391 | Val Loss: 0.7994
# Epoch 40 | Train Loss: 0.7489 | Val Loss: 0.8335
# Epoch 41 | Train Loss: 0.7307 | Val Loss: 0.7904
# Epoch 42 | Train Loss: 0.7329 | Val Loss: 0.7929
# Epoch 43 | Train Loss: 0.7305 | Val Loss: 0.7978
# Epoch 44 | Train Loss: 0.7273 | Val Loss: 0.8192
# Epoch 45 | Train Loss: 0.7156 | Val Loss: 0.8222
# Epoch 46 | Train Loss: 0.7231 | Val Loss: 0.8023
# Epoch 47 | Train Loss: 0.7122 | Val Loss: 0.7983
# Epoch 48 | Train Loss: 0.7048 | Val Loss: 0.8276
# Epoch 49 | Train Loss: 0.7018 | Val Loss: 0.7939
# Epoch 50 | Train Loss: 0.7037 | Val Loss: 0.8054
# Epoch 51 | Train Loss: 0.7030 | Val Loss: 0.8259
# Early stopping triggered
# Training with lr=0.001, hidden_dim=128, pos_weight=None
# Epoch 1 | Train Loss: 0.6933 | Val Loss: 0.6747
# Epoch 2 | Train Loss: 0.6738 | Val Loss: 0.6614
# Epoch 3 | Train Loss: 0.6649 | Val Loss: 0.6638
# Epoch 4 | Train Loss: 0.6548 | Val Loss: 0.6442
# Epoch 5 | Train Loss: 0.6526 | Val Loss: 0.6409
# Epoch 6 | Train Loss: 0.6465 | Val Loss: 0.6335
# Epoch 7 | Train Loss: 0.6422 | Val Loss: 0.6455
# Epoch 8 | Train Loss: 0.6353 | Val Loss: 0.6238
# Epoch 9 | Train Loss: 0.6298 | Val Loss: 0.6249
# Epoch 10 | Train Loss: 0.6225 | Val Loss: 0.6224
# Epoch 11 | Train Loss: 0.6208 | Val Loss: 0.6144
# Epoch 12 | Train Loss: 0.6169 | Val Loss: 0.6147
# Epoch 13 | Train Loss: 0.6071 | Val Loss: 0.6139
# Epoch 14 | Train Loss: 0.6054 | Val Loss: 0.6101
# Epoch 15 | Train Loss: 0.6062 | Val Loss: 0.6184
# Epoch 16 | Train Loss: 0.5956 | Val Loss: 0.6097
# Epoch 17 | Train Loss: 0.5923 | Val Loss: 0.6093
# Epoch 18 | Train Loss: 0.5886 | Val Loss: 0.6098
# Epoch 19 | Train Loss: 0.5774 | Val Loss: 0.6170
# Epoch 20 | Train Loss: 0.5819 | Val Loss: 0.6076
# Epoch 21 | Train Loss: 0.5766 | Val Loss: 0.6048
# Epoch 22 | Train Loss: 0.5729 | Val Loss: 0.5946
# Epoch 23 | Train Loss: 0.5724 | Val Loss: 0.5955
# Epoch 24 | Train Loss: 0.5610 | Val Loss: 0.5934
# Epoch 25 | Train Loss: 0.5577 | Val Loss: 0.5960
# Epoch 26 | Train Loss: 0.5500 | Val Loss: 0.6025
# Epoch 27 | Train Loss: 0.5473 | Val Loss: 0.5975
# Epoch 28 | Train Loss: 0.5440 | Val Loss: 0.5952
# Epoch 29 | Train Loss: 0.5410 | Val Loss: 0.5916
# Epoch 30 | Train Loss: 0.5390 | Val Loss: 0.5929
# Epoch 31 | Train Loss: 0.5327 | Val Loss: 0.5921
# Epoch 32 | Train Loss: 0.5256 | Val Loss: 0.5892
# Epoch 33 | Train Loss: 0.5335 | Val Loss: 0.5914
# Epoch 34 | Train Loss: 0.5342 | Val Loss: 0.5946
# Epoch 35 | Train Loss: 0.5183 | Val Loss: 0.5867
# Epoch 36 | Train Loss: 0.5120 | Val Loss: 0.5801
# Epoch 37 | Train Loss: 0.5081 | Val Loss: 0.5875
# Epoch 38 | Train Loss: 0.5074 | Val Loss: 0.6177
# Epoch 39 | Train Loss: 0.5033 | Val Loss: 0.5812
# Epoch 40 | Train Loss: 0.4983 | Val Loss: 0.5896
# Epoch 41 | Train Loss: 0.4982 | Val Loss: 0.5715
# Epoch 42 | Train Loss: 0.4924 | Val Loss: 0.5775
# Epoch 43 | Train Loss: 0.4857 | Val Loss: 0.5873
# Epoch 44 | Train Loss: 0.4901 | Val Loss: 0.5777
# Epoch 45 | Train Loss: 0.4818 | Val Loss: 0.6068
# Epoch 46 | Train Loss: 0.4809 | Val Loss: 0.5778
# Epoch 47 | Train Loss: 0.4736 | Val Loss: 0.5795
# Epoch 48 | Train Loss: 0.4818 | Val Loss: 0.5935
# Epoch 49 | Train Loss: 0.4748 | Val Loss: 0.5717
# Epoch 50 | Train Loss: 0.4672 | Val Loss: 0.5730
# Epoch 51 | Train Loss: 0.4668 | Val Loss: 0.5891
# Early stopping triggered
# Training with lr=0.001, hidden_dim=128, pos_weight=tensor([2.], device='cuda:0')
# Epoch 1 | Train Loss: 0.9544 | Val Loss: 0.9466
# Epoch 2 | Train Loss: 0.9259 | Val Loss: 0.9070
# Epoch 3 | Train Loss: 0.9109 | Val Loss: 0.9080
# Epoch 4 | Train Loss: 0.9086 | Val Loss: 0.8878
# Epoch 5 | Train Loss: 0.9028 | Val Loss: 0.8978
# Epoch 6 | Train Loss: 0.8943 | Val Loss: 0.9189
# Epoch 7 | Train Loss: 0.8852 | Val Loss: 0.8707
# Epoch 8 | Train Loss: 0.8745 | Val Loss: 0.8706
# Epoch 9 | Train Loss: 0.8736 | Val Loss: 0.8664
# Epoch 10 | Train Loss: 0.8589 | Val Loss: 0.8821
# Epoch 11 | Train Loss: 0.8643 | Val Loss: 0.8506
# Epoch 12 | Train Loss: 0.8435 | Val Loss: 0.8456
# Epoch 13 | Train Loss: 0.8422 | Val Loss: 0.8469
# Epoch 14 | Train Loss: 0.8297 | Val Loss: 0.8437
# Epoch 15 | Train Loss: 0.8225 | Val Loss: 0.8672
# Epoch 16 | Train Loss: 0.8130 | Val Loss: 0.8729
# Epoch 17 | Train Loss: 0.8191 | Val Loss: 0.8412
# Epoch 18 | Train Loss: 0.8036 | Val Loss: 0.8399
# Epoch 19 | Train Loss: 0.7962 | Val Loss: 0.8350
# Epoch 20 | Train Loss: 0.7954 | Val Loss: 0.8335
# Epoch 21 | Train Loss: 0.7820 | Val Loss: 0.8350
# Epoch 22 | Train Loss: 0.7818 | Val Loss: 0.8420
# Epoch 23 | Train Loss: 0.7755 | Val Loss: 0.8309
# Epoch 24 | Train Loss: 0.7682 | Val Loss: 0.8063
# Epoch 25 | Train Loss: 0.7586 | Val Loss: 0.8257
# Epoch 26 | Train Loss: 0.7595 | Val Loss: 0.8049
# Epoch 27 | Train Loss: 0.7507 | Val Loss: 0.8118
# Epoch 28 | Train Loss: 0.7476 | Val Loss: 0.8266
# Epoch 29 | Train Loss: 0.7375 | Val Loss: 0.8086
# Epoch 30 | Train Loss: 0.7486 | Val Loss: 0.8002
# Epoch 31 | Train Loss: 0.7278 | Val Loss: 0.7935
# Epoch 32 | Train Loss: 0.7296 | Val Loss: 0.7996
# Epoch 33 | Train Loss: 0.7210 | Val Loss: 0.8147
# Epoch 34 | Train Loss: 0.7153 | Val Loss: 0.8390
# Epoch 35 | Train Loss: 0.7103 | Val Loss: 0.8227
# Epoch 36 | Train Loss: 0.7051 | Val Loss: 0.8152
# Epoch 37 | Train Loss: 0.7083 | Val Loss: 0.7878
# Epoch 38 | Train Loss: 0.7037 | Val Loss: 0.8920
# Epoch 39 | Train Loss: 0.6991 | Val Loss: 0.7944
# Epoch 40 | Train Loss: 0.6908 | Val Loss: 0.8224
# Epoch 41 | Train Loss: 0.6890 | Val Loss: 0.8183
# Epoch 42 | Train Loss: 0.6822 | Val Loss: 0.8215
# Epoch 43 | Train Loss: 0.6803 | Val Loss: 0.8209
# Epoch 44 | Train Loss: 0.6818 | Val Loss: 0.8667
# Epoch 45 | Train Loss: 0.6856 | Val Loss: 0.8470
# Epoch 46 | Train Loss: 0.6670 | Val Loss: 0.8509
# Epoch 47 | Train Loss: 0.6695 | Val Loss: 0.8023
# Early stopping triggered
# Best params: {'lr': 0.001, 'hidden_dim': 128, 'pos_weight': None, 'input_dim': 30, 'edge_dim': 6}

# %%
def plot_final_layer_weights(model):
    weights = model.lin.weight.detach().cpu().numpy().flatten()

    # Plotting
    plt.figure(figsize=(14, 5))
    plt.bar(range(len(weights)), weights, color=['red' if w > 0 else 'blue' for w in weights])
    plt.axhline(0, color='black', linewidth=0.8)
    plt.title("Final Layer Weights (hERG Toxicity Contribution)")
    plt.xlabel("Latent Feature Index")
    plt.ylabel("Weight (Contribution to Toxicity Prediction)")
    plt.tight_layout()
    plt.savefig("final_layer_weights.png", dpi=300)
    plt.show()

plot_final_layer_weights(model)

# %% [markdown]
# # Evaluation

# %%
model.eval()
y_true = []
y_scores = []

with torch.no_grad():
    for batch in loader:
        batch = batch.to(device)
        logits = model(batch)
        probs = torch.sigmoid(logits)
        y_true.extend(batch.y.cpu().numpy())
        y_scores.extend(probs.cpu().numpy())

y_pred = [1 if p > 0.5 else 0 for p in y_scores]

acc = accuracy_score(y_true, y_pred)
roc_auc = roc_auc_score(y_true, y_scores)
fpr, tpr, _ = roc_curve(y_true, y_scores)

print(f"\n Accuracy: {acc:.4f}")
print(f" ROC AUC: {roc_auc:.4f}")

# 8. Plot ROC curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - hERG GNN")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.savefig("roc.png", dpi=300)
plt.show()
# Out:
#  Accuracy: 0.7089
#  ROC AUC: 0.8367

# %%
# Confusion matrix is more informative than ROC

cm = confusion_matrix(y_true, y_pred)
conf_mat_labels = ['Negative', 'Positive']

plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=conf_mat_labels, yticklabels=conf_mat_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - hERG')
plt.tight_layout()
plt.savefig("conf_matrix.png", dpi=300)
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=conf_mat_labels))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.49      0.63      2240
#     Positive       0.65      0.92      0.76      2240
#
#     accuracy                           0.71      4480
#    macro avg       0.76      0.71      0.69      4480
# weighted avg       0.76      0.71      0.69      4480

# %%
# torch.save({
#     "model_state_dict": model.state_dict()
#     }, "herg_gnn.pt")

# %%
sample_data = mol_to_graph("CCO", 1)
print("Atom feature dim:", sample_data.x.shape[1])  # Should print 30
# Out:
# Atom feature dim: 30

# %%
checkpoint = torch.load("herg_gnn.pt")
print("Saved weight shape:", checkpoint["model_state_dict"]["conv1.lin.weight"].shape)
# Out:
# Saved weight shape: torch.Size([128, 30])

# %%
model = GCN(input_dim=30, edge_dim=6)
state = torch.load("herg_gnn.pt")
model.load_state_dict(state["model_state_dict"])  # This line should succeed!
# Out:
# <All keys matched successfully>
